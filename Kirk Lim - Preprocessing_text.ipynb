# %% [markdown]
# ## The objective of this notebook is to load a dataset of tweets between the several companies and their customers.  The data wrangling is only for the feature "text".  To preserve the original data "text", another column is create named "new_text" to which all the pre-processing operations are done.
#
# Attention:
# 1. Due to the massive file size of the data, this program was not able to complete the task due to limited CPU power of my laptop.  Take not the their is an attached sample file (sample.txt) that is significantly lesser in size which show case how this program processes an input file.
# 2. After investigation, the section that consumes a lot of time is in the spelling correction.  I tried to bypass this, and was able to finish the run.  Please see output.

# %%
import pandas as pd
import EDAHelper as hlpr
# Out:
# C:\Users\k45li\AppData\Local\Temp\ipykernel_23228\3153690647.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\k45li\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\k45li\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\k45li\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
start_time = hlpr.show_time()
print("Start of the run ...",start_time)
# Out:
# Start of the run ... 2024-02-08 12:13:16

# %%
df = pd.read_csv('kdata.csv')
#df = pd.read_csv('sample.csv')

# %%
df
# Out:
#          tweet_id   author_id  inbound                      created_at  \
# 0               1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1               2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2               3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3               4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4               5      115712     True  Tue Oct 31 21:49:35 +0000 2017
# ...           ...         ...      ...                             ...
# 2811769   2987947  sprintcare    False  Wed Nov 22 08:43:51 +0000 2017
# 2811770   2987948      823869     True  Wed Nov 22 08:35:16 +0000 2017
# 2811771   2812240      121673     True  Thu Nov 23 04:13:07 +0000 2017
# 2811772   2987949      AldiUK    False  Wed Nov 22 08:31:24 +0000 2017
# 2811773   2987950      823870     True  Tue Nov 21 22:01:04 +0000 2017
#
#                                                       text response_tweet_id  \
# ...

# %%
df['new_text']=df['text']

# %%
print(df['new_text'].dtype)
# Out:
# object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2811774 entries, 0 to 2811773
# Data columns (total 8 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tweet_id                 int64
#  1   author_id                object
#  2   inbound                  bool
#  3   created_at               object
#  4   text                     object
#  5   response_tweet_id        object
#  6   in_response_to_tweet_id  float64
#  7   new_text                 object
# dtypes: bool(1), float64(1), int64(1), object(5)
# memory usage: 152.8+ MB

# %% [markdown]
# # LOWER CASE

# %%
df['new_text']=df['new_text'].apply(hlpr.lower_cases)

# %%
df
# Out:
#          tweet_id   author_id  inbound                      created_at  \
# 0               1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1               2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2               3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3               4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4               5      115712     True  Tue Oct 31 21:49:35 +0000 2017
# ...           ...         ...      ...                             ...
# 2811769   2987947  sprintcare    False  Wed Nov 22 08:43:51 +0000 2017
# 2811770   2987948      823869     True  Wed Nov 22 08:35:16 +0000 2017
# 2811771   2812240      121673     True  Thu Nov 23 04:13:07 +0000 2017
# 2811772   2987949      AldiUK    False  Wed Nov 22 08:31:24 +0000 2017
# 2811773   2987950      823870     True  Tue Nov 21 22:01:04 +0000 2017
#
#                                                       text response_tweet_id  \
# ...

# %% [markdown]
# # REMOVE HTML TAGS

# %%
df['new_text']=df['new_text'].apply(hlpr.remove_html_tags)

# %%
df
# Out:
#          tweet_id   author_id  inbound                      created_at  \
# 0               1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1               2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2               3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3               4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4               5      115712     True  Tue Oct 31 21:49:35 +0000 2017
# ...           ...         ...      ...                             ...
# 2811769   2987947  sprintcare    False  Wed Nov 22 08:43:51 +0000 2017
# 2811770   2987948      823869     True  Wed Nov 22 08:35:16 +0000 2017
# 2811771   2812240      121673     True  Thu Nov 23 04:13:07 +0000 2017
# 2811772   2987949      AldiUK    False  Wed Nov 22 08:31:24 +0000 2017
# 2811773   2987950      823870     True  Tue Nov 21 22:01:04 +0000 2017
#
#                                                       text response_tweet_id  \
# ...

# %% [markdown]
# # REMOVE ANY URL

# %%
df['new_text']=df['new_text'].apply(hlpr.remove_url)

# %%
df
# Out:
#          tweet_id   author_id  inbound                      created_at  \
# 0               1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1               2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2               3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3               4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4               5      115712     True  Tue Oct 31 21:49:35 +0000 2017
# ...           ...         ...      ...                             ...
# 2811769   2987947  sprintcare    False  Wed Nov 22 08:43:51 +0000 2017
# 2811770   2987948      823869     True  Wed Nov 22 08:35:16 +0000 2017
# 2811771   2812240      121673     True  Thu Nov 23 04:13:07 +0000 2017
# 2811772   2987949      AldiUK    False  Wed Nov 22 08:31:24 +0000 2017
# 2811773   2987950      823870     True  Tue Nov 21 22:01:04 +0000 2017
#
#                                                       text response_tweet_id  \
# ...

# %% [markdown]
# # REMOVE PUNCTUATION MARKS

# %%
df['new_text']=df['new_text'].apply(hlpr.remove_punc)

# %%
df
# Out:
#          tweet_id   author_id  inbound                      created_at  \
# 0               1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1               2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2               3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3               4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4               5      115712     True  Tue Oct 31 21:49:35 +0000 2017
# ...           ...         ...      ...                             ...
# 2811769   2987947  sprintcare    False  Wed Nov 22 08:43:51 +0000 2017
# 2811770   2987948      823869     True  Wed Nov 22 08:35:16 +0000 2017
# 2811771   2812240      121673     True  Thu Nov 23 04:13:07 +0000 2017
# 2811772   2987949      AldiUK    False  Wed Nov 22 08:31:24 +0000 2017
# 2811773   2987950      823870     True  Tue Nov 21 22:01:04 +0000 2017
#
#                                                       text response_tweet_id  \
# ...

# %% [markdown]
# # REMOVE STOPWORDS

# %%
df['new_text']=df['new_text'].apply(hlpr.remove_stopwords)

# %%
df
# Out:
#          tweet_id   author_id  inbound                      created_at  \
# 0               1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1               2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2               3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3               4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4               5      115712     True  Tue Oct 31 21:49:35 +0000 2017
# ...           ...         ...      ...                             ...
# 2811769   2987947  sprintcare    False  Wed Nov 22 08:43:51 +0000 2017
# 2811770   2987948      823869     True  Wed Nov 22 08:35:16 +0000 2017
# 2811771   2812240      121673     True  Thu Nov 23 04:13:07 +0000 2017
# 2811772   2987949      AldiUK    False  Wed Nov 22 08:31:24 +0000 2017
# 2811773   2987950      823870     True  Tue Nov 21 22:01:04 +0000 2017
#
#                                                       text response_tweet_id  \
# ...

# %% [markdown]
# # REMOVE EMOJIS

# %%
df['new_text']=df['new_text'].apply(hlpr.remove_emojis_manually)

# %%
df
# Out:
#          tweet_id   author_id  inbound                      created_at  \
# 0               1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1               2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2               3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3               4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4               5      115712     True  Tue Oct 31 21:49:35 +0000 2017
# ...           ...         ...      ...                             ...
# 2811769   2987947  sprintcare    False  Wed Nov 22 08:43:51 +0000 2017
# 2811770   2987948      823869     True  Wed Nov 22 08:35:16 +0000 2017
# 2811771   2812240      121673     True  Thu Nov 23 04:13:07 +0000 2017
# 2811772   2987949      AldiUK    False  Wed Nov 22 08:31:24 +0000 2017
# 2811773   2987950      823870     True  Tue Nov 21 22:01:04 +0000 2017
#
#                                                       text response_tweet_id  \
# ...

# %%
df.to_csv('kdata_clean.csv')

# %% [markdown]
# # REPLACE CHAT ABBREVIATION WITH WORDS / CHAT WORDS BASED ON https://www.kaggle.com/code/nmaguette/up-to-date-list-of-slangs-for-text-preprocessing/notebook

# %%
df['new_text']=df['new_text'].apply(hlpr.chat_conversion)

# %%
df
# Out:
#          tweet_id   author_id  inbound                      created_at  \
# 0               1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1               2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2               3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3               4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4               5      115712     True  Tue Oct 31 21:49:35 +0000 2017
# ...           ...         ...      ...                             ...
# 2811769   2987947  sprintcare    False  Wed Nov 22 08:43:51 +0000 2017
# 2811770   2987948      823869     True  Wed Nov 22 08:35:16 +0000 2017
# 2811771   2812240      121673     True  Thu Nov 23 04:13:07 +0000 2017
# 2811772   2987949      AldiUK    False  Wed Nov 22 08:31:24 +0000 2017
# 2811773   2987950      823870     True  Tue Nov 21 22:01:04 +0000 2017
#
#                                                       text response_tweet_id  \
# ...

# %% [markdown]
# # SPELL CORRECTION

# %%
#df['new_text']=df['new_text'].apply(hlpr.spell_correction)

# %%
#df

# %% [markdown]
# # TOKENIZE AND STEM THE TOKENS (IF LEMMATIZATION IS DESIRED, SET OPTION_LEMMATIZE = True in the helper file

# %%
df['new_text']=df['new_text'].apply(hlpr.preprocess_text)

# %%
df
# Out:
#          tweet_id   author_id  inbound                      created_at  \
# 0               1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1               2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2               3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3               4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4               5      115712     True  Tue Oct 31 21:49:35 +0000 2017
# ...           ...         ...      ...                             ...
# 2811769   2987947  sprintcare    False  Wed Nov 22 08:43:51 +0000 2017
# 2811770   2987948      823869     True  Wed Nov 22 08:35:16 +0000 2017
# 2811771   2812240      121673     True  Thu Nov 23 04:13:07 +0000 2017
# 2811772   2987949      AldiUK    False  Wed Nov 22 08:31:24 +0000 2017
# 2811773   2987950      823870     True  Tue Nov 21 22:01:04 +0000 2017
#
#                                                       text response_tweet_id  \
# ...

# %%
print("Start of the run ...",start_time)
print("End of the run   ...", hlpr.show_time())
# Out:
# Start of the run ... 2024-02-08 12:13:16
# End of the run   ... 2024-02-08 12:37:23

# %%
df.to_csv('output.csv')
